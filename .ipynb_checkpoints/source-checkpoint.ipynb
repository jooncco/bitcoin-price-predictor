# %% [markdown]
# # <b>Predicting Bitcoin Price with Market Indicators & Trend Data<br>using Regression Models and LSTM RNN</b>
# <b>CSI4117 Data Mining @ Yonsei Univ. Republic of Korea</b>
# <br>
# <br>
# Author: jooncco<br>
# Created: 2018. 6. 2<br>

# %%
import gc
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# <br>
# ## <b>LOAD DATASET</b>

# %%
df = pd.read_csv('price_market.csv')    # 2012~2018
df.set_index(pd.DatetimeIndex(df['Date']), inplace=True)
target = df['BTC_Price']
df = df.drop(['Date', 'BTC_Price'], axis=1)
print('Size of dataset: ', df.shape[0], 'x', df.shape[1])
df.head(5)
# Out:
# Size of dataset:  1583 x 15
#             DOW_Price  NASDAQ_Price  GOLD_Price  USD_Price  US_BCI  US_CCI  \
# Date
# 2012-02-02   12705.41       2859.68      1756.8      79.11  100.07   98.71
# 2012-02-03   12862.23       2905.66      1737.9      79.06  100.07   98.71
# 2012-02-06   12845.13       2901.99      1722.8      79.19  100.07   98.71
# 2012-02-07   12878.20       2904.08      1746.4      78.67  100.07   98.71
# 2012-02-08   12883.95       2915.86      1729.3      78.73  100.07   98.71
#
#              US2TB  US30TB  ETH  XRP  US_INTR      S&P  BTCCash  LTC  Gsearch
# Date
# 2012-02-02  110.37  144.59  0.0  0.0     0.75  1325.54      0.0  0.0        1
# 2012-02-03  110.33  142.41  0.0  0.0     0.75  1344.90      0.0  0.0        1
# 2012-02-06  110.35  143.28  0.0  0.0     0.75  1344.33      0.0  0.0        1
# 2012-02-07  110.31  142.31  0.0  0.0     0.75  1347.05      0.0  0.0        1
# 2012-02-08  110.30  142.22  0.0  0.0     0.75  1349.96      0.0  0.0        1

# %% [markdown]
# <i>Features</i>:<br>
# Stocks : <b>Dow Jones Industrial Index, NASDAQ, S&P 500</b> <br>
# Forex : <b>Gold (comex) Index, USD basket Index</b> <br>
# OECD Economic Statistics : <b>US Business Confidence Index, US Consumer Confidence Index</b> <br>
# Bonds : <b>US-2-year treasury bond futures, US-30-year treasury bond futures</b> <br>
# Other Crypto-currencies : <b>Ethereum, Ripple, BTCCash, Litecoin</b> <br>
# And Google Trends : <b>precentiles of "Bitcoin" searches on Google (1 : bottom 1%, 100 : top 100% percent of searches)</b> <br>

# %%
target.plot(title='Bitcoin Daily Price', style='r')

# %% [markdown]
# We have large dataset spanning from 2012 to 2018, but our main focus here is to predict next-day bitcoin price. In other words, our model will learn to detect local pattern in everyday market & trend data which reflects interday bitcoin price fluctuation.<br><br><br>

# %% [markdown]
# ## <b>DATA EXPLORATION AND VISUALIZATION</b><br>
#
# The volume and number of features of our dataset is too large. So we decided to do as following:<br>
# 1. Slice the time series<br>
# 2. Perform PCA on market data & trend data for variable selection<br>
#
# Only significant parts of our data explorations are shown:<br><br>
#
# 1) Period of interest<br>

# %%
price_2017 = target['20170501':'20180101']
price_2017.plot(title='2017 MAY-DEC Bitcoin Price', style='r')

# %%
price_2018 = target['20180101':'20180301']
price_2018.plot(title='2018 JAN-FEB Bitcoin Price', style='r')

# %% [markdown]
# <br>
# 2) Correlation analysis on features

# %%
def color_high_val(val):
    color = "red" if val > 0.9 else 'black' 
    return 'color: %s' % color
corr_output = df.corr(method = 'pearson', min_periods = 1)
corr_output.style.applymap(color_high_val)
# Out:
# <style  type="text/css" >
#     #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col0 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col1 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col2 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col3 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col4 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col5 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col11 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col12 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col13 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow0_col14 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col0 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col1 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col2 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col3 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col4 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col5 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col11 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col12 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col13 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow1_col14 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col0 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col1 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col2 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col3 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col4 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col5 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col11 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col12 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col13 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow2_col14 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col0 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col1 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col2 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col3 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col4 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col5 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col11 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col12 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col13 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow3_col14 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col0 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col1 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col2 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col3 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col4 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col5 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col11 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col12 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col13 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow4_col14 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col0 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col1 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col2 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col3 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col4 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col5 {
#             color:  red;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col6 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col7 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col8 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col9 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col10 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_col11 {
#             color:  black;
#         }    #T_607ad4a4_6768_11e8_9e56_f44d30adabedrow5_co

# %% [markdown]
# Strong correlation pairs:<br>
# <b>(DOW_Price,NASDAQ_Price), (DOW_Price, S&P), (NASDAQ_Price, S&P), (ETH, XRP), (ETH, BTCCash), (ETH, LTC), (BTCCash, LTC), (BTCCash, Gsearch), (LTC, Gsearch)</b><br><br>

# %%
df_use = df['20170501':'20180301']
target_use = target['20170501':'20180301']
target_use = pd.DataFrame(data=target_use.values, columns=['BTC_Price'])   # get rid of date index

# %%
pair = df_use.loc[:, lambda df_use: ['DOW_Price', 'NASDAQ_Price']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='DOW_Price', y='NASDAQ_Price')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['DOW_Price', 'S&P']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='DOW_Price', y='S&P')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['NASDAQ_Price', 'S&P']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='NASDAQ_Price', y='S&P')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'XRP']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='XRP')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'BTCCash']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='BTCCash')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'LTC']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='LTC')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['BTCCash', 'LTC']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='BTCCash', y='LTC')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['BTCCash', 'Gsearch']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='BTCCash', y='Gsearch')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['LTC', 'Gsearch']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='LTC', y='Gsearch')
pair.plot()

# %% [markdown]
# Based on domain knowledge, we decided candidates for <b>PCA</b>(Principle Component Analysis):<br>
# <b>DOW_Price, NASDAQ_Price, S&P, BTCCash, LTC</b>

# %% [markdown]
# <br>
# ## <b>PREPROCESS OF DATA</b>
# <br>
# <b>1) PCA PROJECTION TO 2-D</b>

# %%
pca_features = ['DOW_Price', 'NASDAQ_Price', 'S&P', 'BTCCash', 'LTC']
temp = df_use.loc[:, lambda df_use: pca_features].values
temp = StandardScaler().fit_transform(temp)             # Normalize

pca = PCA(n_components=2)
principal_components = pca.fit_transform(temp)          # PCA Projection
principalDf = pd.DataFrame(data=principal_components, columns=['pc1', 'pc2'])
principalDf.head()
# Out:
#         pc1       pc2
# 0 -2.606116  0.261020
# 1 -2.583144  0.241431
# 2 -2.587472  0.313998
# 3 -2.570140  0.324893
# 4 -2.480942  0.280163

# %% [markdown]
# <br>
# <b>2) NORMALIZE THE REST DATA</b>

# %%
other_features = ['GOLD_Price','USD_Price','US_BCI','US_CCI','US2TB','US30TB','ETH','XRP','US_INTR','Gsearch']
df_use = df_use.drop(pca_features, axis=1).values
df_use = StandardScaler().fit_transform(df_use)            # Normalize
df_use = pd.DataFrame(data=df_use, columns=other_features)
df_use.head()
# Out:
#    GOLD_Price  USD_Price    US_BCI    US_CCI     US2TB    US30TB       ETH  \
# 0   -0.870003   2.065725 -2.023231  0.047632  0.938386 -0.192119 -1.194125
# 1   -0.829288   2.027541 -2.023231  0.047632  1.019947  0.028910 -1.192204
# 2   -1.060005   2.123002 -2.023231  0.047632  0.922074  0.046592 -1.180296
# 3   -1.600155   1.958808 -2.023231  0.047632  0.856825 -0.274637 -1.138055
# 4   -1.646299   1.912986 -2.023231  0.047632  0.840513 -0.248113 -1.162310
#
#         XRP  US_INTR   Gsearch
# 0 -0.824048      0.0 -0.833332
# 1 -0.824048      0.0 -0.833332
# 2 -0.805845      0.0 -0.833332
# 3 -0.787642      0.0 -0.833332
# 4 -0.769439      0.0 -0.833332

# %% [markdown]
# <br>
# <b>3) CONCATENATE</b>

# %%
finalDf = pd.concat([principalDf, df_use], axis=1)
finalDf.head()
# Out:
#         pc1       pc2  GOLD_Price  USD_Price    US_BCI    US_CCI     US2TB  \
# 0 -2.606116  0.261020   -0.870003   2.065725 -2.023231  0.047632  0.938386
# 1 -2.583144  0.241431   -0.829288   2.027541 -2.023231  0.047632  1.019947
# 2 -2.587472  0.313998   -1.060005   2.123002 -2.023231  0.047632  0.922074
# 3 -2.570140  0.324893   -1.600155   1.958808 -2.023231  0.047632  0.856825
# 4 -2.480942  0.280163   -1.646299   1.912986 -2.023231  0.047632  0.840513
#
#      US30TB       ETH       XRP  US_INTR   Gsearch
# 0 -0.192119 -1.194125 -0.824048      0.0 -0.833332
# 1  0.028910 -1.192204 -0.824048      0.0 -0.833332
# 2  0.046592 -1.180296 -0.805845      0.0 -0.833332
# 3 -0.274637 -1.138055 -0.787642      0.0 -0.833332
# 4 -0.248113 -1.162310 -0.769439      0.0 -0.833332

# %% [markdown]
# <br>
# ## <b>SPLIT THE DATA</b>
# <br>
# TRAIN : TEST = 4 : 1

# %%
train_x, test_x, train_y, test_y = train_test_split(finalDf, target_use, test_size=1/5.0, random_state=0, shuffle=True)

print('Size of TRAIN DATA:', train_x.shape[0], 'x', train_x.shape[1])
print('Size of TRAIN LABEL:', train_y.shape[0], 'x', train_y.shape[1])
print('Size of TEST DATA:', test_x.shape[0], 'x', test_x.shape[1])
print('Size of TEST LABEL:', test_y.shape[0], 'x', test_y.shape[1])
# Out:
# Size of TRAIN DATA: 180 x 12
# Size of TRAIN LABEL: 180 x 1
# Size of TEST DATA: 46 x 12
# Size of TEST LABEL: 46 x 1

# %% [markdown]
# <br>
# ## <b>MODEL TRAINING</b>
# <br>
# <b>Model 1:</b> Linear Regression

# %%
linear_r = LinearRegression()
linear_r.fit(train_x, train_y)
print()

# %% [markdown]
# <br>
# <b>Model 2:</b> Logistic Regression

# %%
logistic_r = LogisticRegression()
train_label_LoR = np.array(train_y).ravel()
enc = preprocessing.LabelEncoder()
train_label_LoR = enc.fit_transform(train_label_LoR)
logistic_r.fit(train_x, train_label_LoR)
print()

# %% [markdown]
# <br>
# <b>Model 3:</b> Support Vector Machine

# %%
svr = SVR(kernel='linear', epsilon=0.1, C=10)
svr.fit(train_x, train_y)
print()
# Out:
# C:\Users\jooncco\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# <br>
# <b>Model 4:</b> K Nearest Neighbor

# %%
knn_regression = KNeighborsRegressor(n_neighbors=5)
knn_regression.fit(train_x, train_y)
print()

# %% [markdown]
# <br>
# <b>Model 5:</b> Recurrent Neural Network (LSTM)
# <br>
# <br>
# - Utility Functions

# %%
def create_input(data, window_size=7):
    '''
    Creates input array from the given dataset
    
    - data: pandas DataFrame instance
    - window_size: look back window size. 7 by default
    
    Returns: python list
    '''
    inputs=[]
    for i in range(len(data)-window_size):
        temp = data[ i : (i+window_size) ].copy()
        inputs.append(temp)
    return inputs

def create_output(data, window_size=7):
    '''
    Creates output array from the given dataset and normalize the data
    
    - data: pandas DataFrame instance
    - window_size: look back window size. 7 by default
    
    Returns: numpy array instance for normalized bitcoin price
    '''
    return (data['BTC_Price'][window_size:].values / data['BTC_Price'][:-window_size].values) - 1

def to_nparray(data):
    '''
    Converts list of inputs into a numpy array
    
    - data: pandas DataFrame
    
    Returns: numpy array
    '''
    x = [np.array(data[i]) for i in range(len(data))]
    return np.array(x)

def build_model(inputs, output_size, num_neurons, activation_func='relu', dropout=0.25, loss='mse', optimizer='adam'):
    '''
    This function builds 3 layered RNN model with LSTM(Long Short-Term Memory) layers and Dense Layer
    
    - inputs: numpy array for input data
    - output_size: number of predictions per input sample
    - num_neurons: number of neurons / units in the LSTM layer
    - activation_func: activation function to be used in LSTM layers & Dense layer
    - dropout: dropout ratio. 0.25 by default
    - loss: loss function for calculating the gradient
    - optimizer: type of optimizer to backpropagate the gradient
    
    Returns: Keras sequential model and model summary
    '''
    model = Sequential()
    model.add(LSTM(num_neurons, return_sequences=True, input_shape=(inputs.shape[1], inputs.shape[2]), activation=activation_func))
    model.add(Dropout(dropout))
    model.add(LSTM(neurons, return_sequences=True, activation=activation_func))
    model.add(Dropout(dropout))
    model.add(LSTM(neurons, activation=activation_func))
    model.add(Dropout(dropout))
    model.add(Dense(units=output_size))
    model.add(Activation(activation_func))
    model.compile(loss=loss, optimizer=optimizer, metrics=['mae'])
    model.summary()
    return model

def plot_results(history, model, x_train, y_train, x_target, y_target):
    plt.figure(figsize=(25, 20))
    plt.subplot(311)
    plt.plot(history.epoch, history.history['loss'], )
    plt.plot(history.epoch, history.history['val_loss'])
    plt.xlabel('Number of Epochs')
    plt.ylabel('Loss')
    plt.title('Model Loss')
    plt.legend(['Training', 'Test'])

    plt.subplot(312)
    plt.plot(y_train)
    plt.plot(model.predict(x_train))
    plt.xlabel('Dates')
    plt.ylabel('Price')
    plt.title('Single Point Price Prediction on Training Set')
    plt.legend(['Actual','Predicted'])
    
    plt.subplot(313)
    plt.plot(y_test)
    plt.plot(model.predict(x_test))
    plt.xlabel('Dates')
    plt.ylabel('Price')
    plt.title('Single Point Price Prediction on Test Set')
    plt.legend(['Actual','Predicted'])

    plt.show()

# %% [markdown]
# <br>
# - Dataset for LSTM aided RNN

# %%
x_train = create_input(train_x)
y_train = create_output(train_y)
x_test = create_input(test_x)
y_test = create_output(test_y)

x_train, x_test = to_nparray(x_train), to_nparray(x_test)

# %% [markdown]
# <br>
# - Model Instantiation

# %%
# hyperparameters
neurons = 512                 
loss = 'mse'                  
batch_size = 12               
epochs = 30

gc.collect()         # clean up the memory
np.random.seed(202)  #random seed for reproducibility
rnn = build_model(x_train, output_size=1, num_neurons=neurons)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 7, 512)            1075200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 7, 512)            2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 512)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,274,113
# Trainable params: 5,274,113
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br>
# - Train

# %%
history = rnn.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=1, validation_data=(x_test, y_test), shuffle=False)
# Out:
# Train on 173 samples, validate on 39 samples
# Epoch 1/30
# 173/173 [==============================] - 8s 44ms/step - loss: 2.9509 - mean_absolute_error: 1.2016 - val_loss: 1.7141 - val_mean_absolute_error: 0.9800
# Epoch 2/30
# 173/173 [==============================] - 6s 32ms/step - loss: 3.2746 - mean_absolute_error: 1.2457 - val_loss: 2.1727 - val_mean_absolute_error: 0.9505
# Epoch 3/30
# 173/173 [==============================] - 6s 33ms/step - loss: 2.7284 - mean_absolute_error: 1.0939 - val_loss: 1.5233 - val_mean_absolute_error: 0.9387
# Epoch 4/30
# 173/173 [==============================] - 6s 36ms/step - loss: 2.2296 - mean_absolute_error: 1.1342 - val_loss: 2.0027 - val_mean_absolute_error: 1.1654
# Epoch 5/30
# 173/173 [==============================] - 6s 35ms/step - loss: 2.4272 - mean_absolute_error: 1.1429 - val_loss: 1.4606 - val_mean_absolute_error: 0.8684
# Epoch 6/30
# 173/173 [==============================] - 6s 33ms/step - loss: 1.8248 - mean_absolute_error: 1.0387 - val_loss: 2.5907 - val_mean_absolute_error: 1.1682
# Epoch 7/30
# 173/173 [==============================] - 6s 37ms/step - loss: 2.0043 - mean_absolute_error: 1.0696 - val_loss: 1.9208 - val_mean_absolute_error: 1.0060
# Epoch 8/30
# 173/173 [==============================] - 7s 39ms/step - loss: 1.7249 - mean_absolute_error: 1.0065 - val_loss: 2.1616 - val_mean_absolute_error: 0.9576
# Epoch 9/30
# 173/173 [==============================] - 7s 39ms/step - loss: 2.0014 - mean_absolute_error: 0.9804 - val_loss: 1.6272 - val_mean_absolute_error: 0.9793
# Epoch 10/30
# 173/173 [==============================] - 6s 34ms/step - loss: 1.7315 - mean_absolute_error: 1.0665 - val_loss: 1.6609 - val_mean_absolute_error: 0.9183
# Epoch 11/30
# 173/173 [==============================] - 6s 36ms/step - loss: 1.5190 - mean_absolute_error: 0.9415 - val_loss: 2.1232 - val_mean_absolute_error: 0.9504
# Epoch 12/30
# 173/173 [==============================] - 7s 38ms/step - loss: 1.7158 - mean_absolute_error: 0.9503 - val_loss: 1.7129 - val_mean_absolute_error: 0.8535
# Epoch 13/30
# 173/173 [==============================] - 6s 35ms/step - loss: 1.5586 - mean_absolute_error: 0.9366 - val_loss: 2.1161 - val_mean_absolute_error: 0.9778
# Epoch 14/30
# 173/173 [==============================] - 6s 35ms/step - loss: 1.4512 - mean_absolute_error: 0.9002 - val_loss: 2.5178 - val_mean_absolute_error: 1.0373
# Epoch 15/30
# 173/173 [==============================] - 6s 34ms/step - loss: 2.0267 - mean_absolute_error: 0.9617 - val_loss: 1.4653 - val_mean_absolute_error: 0.8617
# Epoch 16/30
# 173/173 [==============================] - 6s 34ms/step - loss: 1.5282 - mean_absolute_error: 0.9902 - val_loss: 1.6927 - val_mean_absolute_error: 0.9132
# Epoch 17/30
# 173/173 [==============================] - 6s 37ms/step - loss: 1.2526 - mean_absolute_error: 0.8776 - val_loss: 4.0545 - val_mean_absolute_error: 1.1506
# Epoch 18/30
# 173/173 [==============================] - 6s 35ms/step - loss: 1.1367 - mean_absolute_error: 0.8302 - val_loss: 3.4385 - val_mean_absolute_error: 1.0506
# Epoch 19/30
# 173/173 [==============================] - 6s 34ms/step - loss: 1.1012 - mean_absolute_error: 0.8167 - val_loss: 1.9840 - val_mean_absolute_error: 0.9355
# Epoch 20/30
# 173/173 [==============================] - 6s 37ms/step - loss: 1.1641 - mean_absolute_error: 0.8389 - val_loss: 2.3168 - val_mean_absolute_error: 0.9893
# Epoch 21/30
# 173/173 [==============================] - 6s 34ms/step - loss: 1.7533 - mean_absolute_error: 0.9518 - val_loss: 2.2084 - val_mean_absolute_error: 0.9191
# Epoch 22/30
# 173/173 [==============================] - 6s 37ms/step - loss: 2.2588 - mean_absolute_error: 1.0077 - val_loss: 1.4000 - val_mean_absolute_error: 0.8345
# Epoch 23/30
# 173/173 [==============================] - 6s 34ms/step - loss: 1.6125 - mean_absolute_error: 0.8810 - val_loss: 2.7075 - val_mean_absolute_error: 1.0823
# Epoch 24/30
# 173/173 [==============================] - 6s 32ms/step - loss: 1.1289 - mean_absolute_error: 0.8073 - val_loss: 2.5649 - val_mean_absolute_error: 1.0218
# Epoch 25/30
# 173/173 [==============================] - 6s 32ms/step - loss: 1.1112 - mean_absolute_error: 0.7606 - val_loss: 2.9202 - val_mean_absolute_error: 1.1142
# Epoch 26/30
# 173/173 [==============================] - 6s 32ms/step - loss: 1.4847 - mean_absolute_error: 0.8584 - val_loss: 2.0057 - val_mean_absolute_error: 1.0672
# Epoch 27/30
# 173/173 [==============================] - 6s 32ms/step - loss: 1.5603 - mean_absolute_error: 0.9258 - val_loss: 1.5779 - val_mean_absolute_error: 0.8705
# Epoch 28/30
# 173/173 [==============================] - 6s 32ms/step - loss: 1.1644 - mean_absolute_error: 0.8295 - val_loss: 1.8399 - val_mean_absolute_error: 0.9540
# Epoch 29/30
# 173/173 [==============================] - 6s 32ms/step - loss: 0.9818 - mean_absolute_error: 0.7285 - val_loss: 2.2836 - val_mean_absolute_error: 1.0284
# Epoch 30/30
# 173/173 [==============================] - 6s 32ms/step - loss: 0.8118 - mean_absolute_error: 0.6979 - val_loss: 2.8745 - val_mean_absolute_error: 1.0986

# %% [markdown]
# <br>
# ## <b>VALIDATION</b>

# %% [markdown]
# <br>
# <b>Model 1:</b> Linear Regression

# %%
print('linear r^2 score : {:.4f}'.format(linear_r.score(test_x, test_y)))
print('linear rmse score : {:.4f}'.format(metrics.mean_squared_error(test_y, linear_r.predict(test_x))))
# Out:
# linear r^2 score : 0.9609
# linear rmse score : 850274.7731

# %% [markdown]
# <br>
# <b>Model 2:</b> Logistic Regression

# %%
test_label_LoR = np.array(test_y).ravel()
enc = preprocessing.LabelEncoder()
test_label_LoR = enc.fit_transform(test_label_LoR)

print('logistic r^2 score : {:.4f}'.format(logistic_r.score(test_x, test_label_LoR)))
print('logistic rmse score : {:.4f}'.format(metrics.mean_squared_error(test_label_LoR, logistic_r.predict(test_x))))
# Out:
# logistic r^2 score : 0.0000
# logistic rmse score : 7412.2826

# %% [markdown]
# <br>
# <b>Model 3:</b> Support Vector Machine

# %%
print('svr r^2 score : {:.4f}'.format(svr.score(test_x, test_y)))
print('svr rmse score : {:.4f}'.format(metrics.mean_squared_error(test_y, svr.predict(test_x))))
# Out:
# svr r^2 score : 0.8643
# svr rmse score : 2950590.8744

# %% [markdown]
# <br>
# <b>Model 4:</b> K Nearest Neighbor

# %%
print('knn r^2 score : {:.4f}'.format(knn_regression.score(test_x, test_y)))
print('knn rmse score : {:.4f}'.format(metrics.mean_squared_error(test_y, knn_regression.predict(test_x))))
# Out:
# knn r^2 score : 0.9756
# knn rmse score : 530491.4461

# %% [markdown]
# <br>
# <b>Model 5:</b> Recurrent Neural Network

# %%
plot_results(history, rnn, x_train, y_train, x_test, y_test)
scores = rnn.evaluate(x_test, y_test, verbose=0)
print('%s: %.2f%%' % (rnn.metrics_names[1], scores[1]))
# Out:
# mean_absolute_error: 1.10%

# %% [markdown]
# <br>
# ## <b>POSSIBLE IMPROVEMENTS</b>
# <br>
# <b>1. PCA step:</b> I conducted PCA just for the primisive 5 features which have strong correlations. But I can simply conduct PCA for the whole columns, with PCA parameter <b>n_components</b> = 12.
# <br>
# <b>2. Data ablation study:</b> we can obtain better refined dataset by trying all the combinations of data.
# <br>
# <b>3. RNN model:</b> As you can see in the summary above, the RNN model used here has 3 LSTM layers. This is not the optimal model which still can be improved.

# %% [markdown]
# ## REFERENCE
# 1) Data & Linear Regression:<br>
# https://www.kaggle.com/acornec/bitcoin-predictions<br>
# 2) Data Exploration:<br>
# https://github.com/anvithaananth/bitcoin_marketprice_prediction/blob/master/project1_bitcoin_final_submission.ipynb<br>
# 3) PCA:<br>
# https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60<br>
# 4) Regression Models:<br>
# https://towardsdatascience.com/logistic-regression-using-python-sklearn-numpy-mnist-handwriting-recognition-matplotlib-a6b31e2b166a<br>
# https://github.com/mGalarnyk/Python_Tutorials/blob/master/Sklearn/PCA/PCA_to_Speed-up_Machine_Learning_Algorithms.ipynb<br>
# 5) RNN:<br>
# https://medium.com/@siavash_37715/how-to-predict-bitcoin-and-ethereum-price-with-rnn-lstm-in-keras-a6d8ee8a5109<br>
