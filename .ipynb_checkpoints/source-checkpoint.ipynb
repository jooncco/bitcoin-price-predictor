# %% [markdown]
# ## CSI4117 Data Mining @ Yonsei Univ. Republic of Korea

# %% [markdown]
# ## <b><i><h>Predicting Bitcoin Price with Market Indicators & Trend Data</h></i></b>
# Author: jooncco<br>
# Created: 2018. 6. 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# <br>
# ## <b>LOAD DATASET</b>

# %%
df = pd.read_csv('price_market.csv')    # 2012~2018
df.set_index(pd.DatetimeIndex(df['Date']), inplace=True)
target = df['BTC_Price']
df = df.drop(['Date', 'BTC_Price'], axis=1)
print('Size of dataset: ', df.shape[0], 'x', df.shape[1])
df.head(5)
# Out:
# Size of dataset:  1583 x 15
#             DOW_Price  NASDAQ_Price  GOLD_Price  USD_Price  US_BCI  US_CCI  \
# Date
# 2012-02-02   12705.41       2859.68      1756.8      79.11  100.07   98.71
# 2012-02-03   12862.23       2905.66      1737.9      79.06  100.07   98.71
# 2012-02-06   12845.13       2901.99      1722.8      79.19  100.07   98.71
# 2012-02-07   12878.20       2904.08      1746.4      78.67  100.07   98.71
# 2012-02-08   12883.95       2915.86      1729.3      78.73  100.07   98.71
#
#              US2TB  US30TB  ETH  XRP  US_INTR      S&P  BTCCash  LTC  Gsearch
# Date
# 2012-02-02  110.37  144.59  0.0  0.0     0.75  1325.54      0.0  0.0        1
# 2012-02-03  110.33  142.41  0.0  0.0     0.75  1344.90      0.0  0.0        1
# 2012-02-06  110.35  143.28  0.0  0.0     0.75  1344.33      0.0  0.0        1
# 2012-02-07  110.31  142.31  0.0  0.0     0.75  1347.05      0.0  0.0        1
# 2012-02-08  110.30  142.22  0.0  0.0     0.75  1349.96      0.0  0.0        1

# %% [markdown]
# <i>Features</i>:<br>
# Stocks : <b>Dow Jones Industrial Index, NASDAQ, S&P 500</b> <br>
# Forex : <b>Gold (comex) Index, USD basket Index</b> <br>
# OECD Economic Statistics : <b>US Business Confidence Index, US Consumer Confidence Index</b> <br>
# Bonds : <b>US-2-year treasury bond futures, US-30-year treasury bond futures</b> <br>
# Other Crypto-currencies : <b>Ethereum, Ripple, BTCCash, Litecoin</b> <br>
# And Google Trends : <b>precentiles of "Bitcoin" searches on Google (1 : bottom 1%, 100 : top 100% percent of searches)</b> <br>

# %%
target.plot(title='Bitcoin Daily Price', style='r')

# %% [markdown]
# We have large dataset spanning from 2012 to 2018, but our main focus here is to predict next-day bitcoin price. In other words, our model will learn to detect local pattern in everyday market & trend data which reflects interday bitcoin price fluctuation.<br><br><br>

# %% [markdown]
# ## <b>DATA EXPLORATION AND VISUALIZATION</b><br>
#
# The volume and number of features of our dataset is too large. So we decided to do as following:<br>
# 1. Slice the time series<br>
# 2. Perform PCA on market data & trend data for variable selection<br>
#
# Only significant parts of our data explorations are shown:<br><br>
#
# 1) Period of interest<br>

# %%
price_2017 = target['20170501':'20180101']
price_2017.plot(title='2017 MAY-DEC Bitcoin Price', style='r')

# %%
price_2018 = target['20180101':'20180301']
price_2018.plot(title='2018 JAN-FEB Bitcoin Price', style='r')

# %% [markdown]
# <br>
# 2) Correlation analysis on features

# %%
def color_high_val(val):
    color = "red" if val > 0.9 else 'black' 
    return 'color: %s' % color
corr_output = df.corr(method = 'pearson', min_periods = 1)
corr_output.style.applymap(color_high_val)
# Out:
# <style  type="text/css" >
#     #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col0 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col1 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col2 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col3 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col4 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col5 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col11 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col12 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col13 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow0_col14 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col0 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col1 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col2 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col3 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col4 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col5 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col11 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col12 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col13 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow1_col14 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col0 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col1 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col2 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col3 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col4 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col5 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col11 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col12 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col13 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow2_col14 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col0 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col1 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col2 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col3 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col4 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col5 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col11 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col12 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col13 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow3_col14 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col0 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col1 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col2 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col3 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col4 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col5 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col11 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col12 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col13 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow4_col14 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col0 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col1 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col2 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col3 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col4 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col5 {
#             color:  red;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col6 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col7 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col8 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col9 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col10 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_col11 {
#             color:  black;
#         }    #T_9e0590b4_672f_11e8_94e4_3c15c2bdcc5crow5_co

# %% [markdown]
# Strong correlation pairs:<br>
# <b>(DOW_Price,NASDAQ_Price), (DOW_Price, S&P), (NASDAQ_Price, S&P), (ETH, XRP), (ETH, BTCCash), (ETH, LTC), (BTCCash, LTC), (BTCCash, Gsearch), (LTC, Gsearch)</b><br><br>

# %%
df_use = df['20170501':'20180301']
target_use = target['20170501':'20180301']
target_use = pd.DataFrame(data=target_use.values, columns=['BTC_Price'])   # get rid of date index

# %%
pair = df_use.loc[:, lambda df_use: ['DOW_Price', 'NASDAQ_Price']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='DOW_Price', y='NASDAQ_Price')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['DOW_Price', 'S&P']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='DOW_Price', y='S&P')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['NASDAQ_Price', 'S&P']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='NASDAQ_Price', y='S&P')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'XRP']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='XRP')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'BTCCash']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='BTCCash')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['ETH', 'LTC']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='ETH', y='LTC')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['BTCCash', 'LTC']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='BTCCash', y='LTC')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['BTCCash', 'Gsearch']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='BTCCash', y='Gsearch')
pair.plot()

# %%
pair = df_use.loc[:, lambda df_use: ['LTC', 'Gsearch']]
pair = (pair-pair.mean())/pair.std()   # Normalize
pair.plot.scatter(x='LTC', y='Gsearch')
pair.plot()

# %% [markdown]
# Based on domain knowledge, we decided candidates for <b>PCA</b>(Principle Component Analysis):<br>
# <b>DOW_Price, NASDAQ_Price, S&P, BTCCash, LTC</b>

# %% [markdown]
# <br>
# ## <b>PREPROCESS OF DATA</b>
# <br>
# <b>1) PCA PROJECTION TO 2-D</b>

# %%
pca_features = ['DOW_Price', 'NASDAQ_Price', 'S&P', 'BTCCash', 'LTC']
temp = df_use.loc[:, lambda df_use: pca_features].values
temp = StandardScaler().fit_transform(temp)             # Normalize

pca = PCA(n_components=2)
principal_components = pca.fit_transform(temp)          # PCA Projection
principalDf = pd.DataFrame(data=principal_components, columns=['pc1', 'pc2'])
principalDf.head()
# Out:
#         pc1       pc2
# 0 -2.606116  0.261020
# 1 -2.583144  0.241431
# 2 -2.587472  0.313998
# 3 -2.570140  0.324893
# 4 -2.480942  0.280163

# %% [markdown]
# <br>
# <b>2) NORMALIZE THE REST DATA</b>

# %%
other_features = ['GOLD_Price','USD_Price','US_BCI','US_CCI','US2TB','US30TB','ETH','XRP','US_INTR','Gsearch']
df_use = df_use.drop(pca_features, axis=1).values
df_use = StandardScaler().fit_transform(df_use)            # Normalize
df_use = pd.DataFrame(data=df_use, columns=other_features)
df_use.head()
# Out:
#    GOLD_Price  USD_Price    US_BCI    US_CCI     US2TB    US30TB       ETH  \
# 0   -0.870003   2.065725 -2.023231  0.047632  0.938386 -0.192119 -1.194125
# 1   -0.829288   2.027541 -2.023231  0.047632  1.019947  0.028910 -1.192204
# 2   -1.060005   2.123002 -2.023231  0.047632  0.922074  0.046592 -1.180296
# 3   -1.600155   1.958808 -2.023231  0.047632  0.856825 -0.274637 -1.138055
# 4   -1.646299   1.912986 -2.023231  0.047632  0.840513 -0.248113 -1.162310
#
#         XRP  US_INTR   Gsearch
# 0 -0.824048      0.0 -0.833332
# 1 -0.824048      0.0 -0.833332
# 2 -0.805845      0.0 -0.833332
# 3 -0.787642      0.0 -0.833332
# 4 -0.769439      0.0 -0.833332

# %% [markdown]
# <br>
# <b>3) CONCATENATE</b>

# %%
finalDf = pd.concat([principalDf, df_use], axis=1)
finalDf.head()
# Out:
#         pc1       pc2  GOLD_Price  USD_Price    US_BCI    US_CCI     US2TB  \
# 0 -2.606116  0.261020   -0.870003   2.065725 -2.023231  0.047632  0.938386
# 1 -2.583144  0.241431   -0.829288   2.027541 -2.023231  0.047632  1.019947
# 2 -2.587472  0.313998   -1.060005   2.123002 -2.023231  0.047632  0.922074
# 3 -2.570140  0.324893   -1.600155   1.958808 -2.023231  0.047632  0.856825
# 4 -2.480942  0.280163   -1.646299   1.912986 -2.023231  0.047632  0.840513
#
#      US30TB       ETH       XRP  US_INTR   Gsearch
# 0 -0.192119 -1.194125 -0.824048      0.0 -0.833332
# 1  0.028910 -1.192204 -0.824048      0.0 -0.833332
# 2  0.046592 -1.180296 -0.805845      0.0 -0.833332
# 3 -0.274637 -1.138055 -0.787642      0.0 -0.833332
# 4 -0.248113 -1.162310 -0.769439      0.0 -0.833332

# %% [markdown]
# <br>
# ## <b>SPLIT THE DATA</b>
# <br>
# TRAIN : TEST = 4 : 1

# %%
train_x, test_x, train_y, test_y = train_test_split(finalDf, target_use, test_size=1/5.0, random_state=0, shuffle=False)

print('Size of TRAIN DATA:', train_x.shape[0], 'x', train_x.shape[1])
print('Size of TRAIN LABEL:', train_y.shape[0], 'x', train_y.shape[1])
print('Size of TEST DATA:', test_x.shape[0], 'x', test_x.shape[1])
print('Size of TEST LABEL:', test_y.shape[0], 'x', test_y.shape[1])
# Out:
# Size of TRAIN DATA: 180 x 12
# Size of TRAIN LABEL: 180 x 1
# Size of TEST DATA: 46 x 12
# Size of TEST LABEL: 46 x 1

# %% [markdown]
# <br>
# ## <b>MODEL TRAINING</b>
# <br>
# <b>Model 1:</b> Logistic Regression

# %% [markdown]
# <br>
# <b>Model 2:</b> Support Vector Machine

# %% [markdown]
# <br>
# <b>Model 3:</b> K Nearest Neighbor

# %% [markdown]
# <br>
# <b>Model 4:</b> Recurrent Neural Network
# <br>
# <br>
# - Model Instantiation

# %%
neurons = 512                 
activation_function = 'tanh'  
loss = 'mse'                  
optimizer='adam'              
dropout = 0.25                 
batch_size = 12               
epochs = 53                   
window_len = 7
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(512, return_sequences=True, activation="relu", input_shape=(None, 12))`
#   # This is added back by InteractiveShellApp.init_path()
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, None, 512)         1075200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 512)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 512)         2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 512)         0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 5,274,113.0
# Trainable params: 5,274,113.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# <br>
# - Train

# %% [markdown]
# <br>
# ## <b>VALIDATION</b>

# %% [markdown]
# <br>
# <b>Model 1:</b> Logistic Regression

# %% [markdown]
# <br>
# <b>Model 2:</b> Support Vector Machine

# %% [markdown]
# <br>
# <b>Model 3:</b> K Nearest Neighbor

# %% [markdown]
# <br>
# <b>Model 4:</b> Recurrent Neural Network

# %% [markdown]
# <br>
# ## <b>RESULT</b>
# <b>DATA ABLATION STUDY</b>

# %% [markdown]
# <br>
# ## <b>POSSIBLE IMPROVEMENTS</b>
# <br>
# <b>1. PCA step:</b> I conducted PCA just for the primisive 5 features which have strong correlations. But I can simply conduct PCA for the whole columns, with PCA parameter <b>n_components</b> = 12.

# %% [markdown]
# ## REFERENCE
# 1) data & Linear Regression:<br>
# https://www.kaggle.com/acornec/bitcoin-predictions<br>
# 2) data exploration:<br>
# https://github.com/anvithaananth/bitcoin_marketprice_prediction/blob/master/project1_bitcoin_final_submission.ipynb<br>
# 3) PCA:<br>
# https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60<br>
# 4) Logistic Regression:<br>
# https://towardsdatascience.com/logistic-regression-using-python-sklearn-numpy-mnist-handwriting-recognition-matplotlib-a6b31e2b166a<br>
# https://github.com/mGalarnyk/Python_Tutorials/blob/master/Sklearn/PCA/PCA_to_Speed-up_Machine_Learning_Algorithms.ipynb<br>
# 5) RNN:<br>
# https://medium.com/@siavash_37715/how-to-predict-bitcoin-and-ethereum-price-with-rnn-lstm-in-keras-a6d8ee8a5109<br>
# https://towardsdatascience.com/bitcoin-price-prediction-using-lstm-9eb0938c22bd
